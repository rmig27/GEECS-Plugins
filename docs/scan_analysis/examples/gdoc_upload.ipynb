# %% [markdown]
# # Google Docs Auto-Upload for Scan Analysis
#
# This notebook documents and exercises the automatic uploading of summary figures into the daily Google Docs scan log (issue #286).
#
# Analyzers with `gdoc_slot` set will have their last summary figure inserted into the corresponding cell of a 2×2 display table in the scan entry after each analysis completes.  See the [live_watch notebook](live_watch.ipynb) for the full live-running workflow.
#
# ## Enabling slot-based uploads in an analyzer config
#
# Add `gdoc_slot` to any analyzer entry in your experiment YAML:
#
# ```yaml
# analyzers:
#   - type: array2d
#     device_name: UC_GaiaMode
#     priority: 0
#     gdoc_slot: 0        # 0 → row 1 col 0 | 1 → row 1 col 1
#                         # 2 → row 2 col 0 | 3 → row 2 col 1
#     image_analyzer:
#       analyzer_class: image_analysis.offline_analyzers.beam_analyzer.BeamAnalyzer
#       camera_config_name: UC_GaiaMode
# ```
#
# Analyzers **without** `gdoc_slot` will have their display files uploaded to the per-day Drive folder and appended as hyperlinks (coming in the next PR).
#
# ## Persistent Drive folder (recommended)
#
# By default images are uploaded to a shared staging folder that is periodically purged.  To store images permanently, add `ImageParentFolderID` to your experiment INI (e.g. `HTUparameters.ini`):
#
# ```ini
# [DEFAULT]
# LogID               = <today's doc id, updated by createExperimentLog>
# ImageParentFolderID = <drive folder id for permanent image storage>
# ```
#
# A per-day subfolder (`YYYY-MM-DD`) is created automatically inside that parent folder.

# %%
import logging

from geecs_data_utils import ScanPaths, ScanTag
from geecs_data_utils.config_roots import image_analysis_config, scan_analysis_config

# Show only gdoc-related logs by default; increase verbosity as needed
for name in ("image_analysis", "scan_analysis", "geecs_data_utils"):
    logging.getLogger(name).setLevel(logging.ERROR)
logging.getLogger("scan_analysis.gdoc_upload").setLevel(logging.INFO)
logging.getLogger("scan_analysis.task_queue").setLevel(logging.INFO)

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s  %(levelname)-8s  %(name)s \u2014 %(message)s",
)

image_analysis_config.set_base_dir(ScanPaths.paths_config.image_analysis_configs_path)
scan_analysis_config.set_base_dir(ScanPaths.paths_config.scan_analysis_configs_path)
# Out:
# config.ini Paths.config_root invalid: 'str' object has no attribute 'exists'
# WindowsPath('C:/Users/loasis.LOASIS/Desktop/Scripts/People/Rachel/git_repos/GEECS-Plugins-Configs/scan_analysis_configs')

# %% [markdown]
# ## Mode 1 — Direct upload (fastest test)
#
# Upload a single known image to a specific table cell.  Useful for verifying
# that Drive upload and `insertImageToTableCell` work before running any analysis.

# %%
from scan_analysis.gdoc_upload import upload_summary_to_gdoc

# ── edit these ──────────────────────────────────────────────────────────────────────────
scan_tag = ScanTag(year=2026, month=3, day=23, number=7, experiment="Undulator")

image_path = "Z:\\data\\Undulator\\Y2026\\03-Mar\\26_0323\\analysis\\Scan007\\UC_DonDSampleArea\\Array2DScanAnalyzer\\UC_DonDSampleArea_average_processed_visual.png"  # any PNG on disk

# Paste from the Google Doc URL: https://docs.google.com/document/d/<DOC_ID>/edit
# Leave as None to use the ID stored in HTUparameters.ini
document_id = "1IOzeFGcsy2gZ6Hp6hEC9CDYD9bfcDtsXx0mn5NJpWXI"

gdoc_slot = 0  # 0–3
# ────────────────────────────────────────────────────────────────────────────

ok = upload_summary_to_gdoc(
    scan_tag=scan_tag,
    display_files=[image_path],
    gdoc_slot=gdoc_slot,
    document_id=document_id,
)
print("Upload succeeded" if ok else "Upload failed or skipped (check logs)")
# Out:
# 2026-07-10 16:18:09,345  WARNING   logmaker_4_googledocs.docgen — Could not load config file from C:\Users\loasis.LOASIS\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\LogMaker4GoogleDocs\logmaker_4_googledocs\config.ini; Apps Script calls will be unavailable.
# 2026-07-10 16:18:09,347  WARNING   logmaker_4_googledocs.docgen — 'script' key missing in C:\Users\loasis.LOASIS\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\LogMaker4GoogleDocs\logmaker_4_googledocs\config.ini; Apps Script calls will be unavailable.
# 2026-07-10 16:18:09,347  INFO      scan_analysis.gdoc_upload — Loaded logmaker_4_googledocs.docgen successfully.
# 2026-07-10 16:18:09,361  ERROR     scan_analysis.gdoc_upload — Failed to upload display file to gdoc for scan year=2026 month=3 day=23 number=7 experiment='Undulator' slot 0: Credentials file not found at: C:\Users\loasis.LOASIS\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\LogMaker4GoogleDocs\logmaker_4_googledocs\credentials.json
# Traceback (most recent call last):
#   File "C:\Users\loasis.LOASIS\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\ScanAnalysis\scan_analysis\gdoc_upload.py", line 131, in upload_summary_to_gdoc
#     success = DOCGEN.insertImageToExperimentLog(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\loasis.LOASIS\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\LogMaker4GoogleDocs\logmaker_4_googledocs\docgen.py", line 1210, in insertImageToExperimentLog
#     image_id = uploadImage(image_path, image_folder_id)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\loasis.LOASIS\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\LogMaker4GoogleDocs\logmaker_4_googledocs\docgen.py", line 725, in uploadImage
#     driveservice = establishService(API_SERVICE_NAME, API_VERSION)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\loasis.LOASIS\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\LogMaker4GoogleDocs\logmaker_4_googledocs\docgen.py", line 438, in establishService
#     raise FileNotFoundError(
# FileNotFoundError: Credentials file not found at: C:\Users\loasis.LOASIS\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\LogMaker4GoogleDocs\logmaker_4_googledocs\credentials.json
# Upload failed or skipped (check logs)

# %% [markdown]
# ## Mode 2 — Full pipeline replay on a historical date
#
# Uses `LiveTaskRunner` against a past date exactly as it would run live.
# `rerun_completed=True` resets any previously-done analyses back to queued so
# they execute again, and `display_files` are written to the status YAMLs as
# they complete. By default, gdoc uploading is disabled in teh LiveTaskRunner
# and must be explicitly enabled using `gdoc_enabled=True`
#
# > **Note on the document ID:** By default `LiveTaskRunner` reads `LogID` from
# > the experiment INI on every upload, which is the correct behaviour for live
# > running (the INI is updated to today's doc each morning).  For a historical
# > backtest, pass `document_id="<old_doc_id>"` directly to `LiveTaskRunner` so
# > you don't have to edit the INI file.  Find the ID in the doc URL:
# > `https://docs.google.com/document/d/<DOC_ID>/edit`.

# %%
import time

from scan_analysis.live_task_runner import LiveTaskRunner

logging.getLogger("scan_analysis.live_task_runner").setLevel(logging.INFO)

# ── edit these ──────────────────────────────────────────────────────────────────────────
date_tag = ScanTag(year=2026, month=2, day=12, number=0, experiment="Undulator")
analyzer_group = "Undulator_test"  # name of the experiment config to load
# ────────────────────────────────────────────────────────────────────────────

# Paste the ID from the historical Google Doc URL, or leave None to read from
# HTUparameters.ini (correct for live running; must be set manually for backtest).
document_id = "1s69sjSeKmk_OGPRKwd-iNUSa3FflV8YP9xEuHG6C5Vo"  # e.g. "1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgVE2upms"
# ────────────────────────────────────────────────────────────────────────────

runner = LiveTaskRunner(
    analyzer_group=analyzer_group,
    date_tag=date_tag,
    config_dir=scan_analysis_config.base_dir,
    image_config_dir=image_analysis_config.base_dir,
    document_id=document_id,
    gdoc_enabled=True,
)

runner.start()
try:
    while True:
        runner.process_new(
            base_directory=ScanPaths.paths_config.base_path,
            max_items=1,
            dry_run=False,
            rerun_completed=True,  # re-run analyses already marked done
            rerun_failed=True,
        )
        time.sleep(1)
finally:
    runner.stop()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 17
#      14 document_id = "1s69sjSeKmk_OGPRKwd-iNUSa3FflV8YP9xEuHG6C5Vo"  # e.g. "1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgVE2upms"
#      15 # ────────────────────────────────────────────────────────────────────────────
# ---> 17 runner = LiveTaskRunner(
#      18     analyzer_group=analyzer_group,
#      19     date_tag=date_tag,
#      20     config_dir=scan_analysis_config.base_dir,
#      21     image_config_dir=image_analysis_config.base_dir,
#      22     document_id=document_id,
#      23     gdoc_enabled=True,
#      24 )
#      26 runner.start()
#      27 try:
#
# File ~\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\ScanAnalysis\scan_analysis\live_task_runner.py:124, in LiveTaskRunner.__init__(self, analyzer_group, date_tag, config_dir, image_config_dir, gdoc_enabled, document_id)
#     121 if image_config_dir:
#     122     image_analysis_config.set_base_dir(image_config_dir)
# --> 124 self.analyzers = load_analyzers_from_config(
#     125     analyzer_group, config_dir=scan_analysis_config.base_dir
#     126 )
#     127 self.queue: Queue = Queue()
#     128 self.observer = PollingObserver()
#
# File ~\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\ScanAnalysis\scan_analysis\task_queue.py:612, in load_analyzers_from_config(group_name, config_dir)
#     591 def load_analyzers_from_config(
#     592     group_name: str, *, config_dir: Optional[Path] = None
#     593 ) -> List[object]:
#     594     """Load and instantiate analyzers for an analysis group, sorted by priority.
#     595
#     596     Parameters
#    (...)
#     610         Runnable :class:`ScanAnalyzer` instances in execution order.
#     611     """
# --> 612     group = load_analysis_group(group_name, config_dir=config_dir)
#     613     return [
#     614         create_scan_analyzer(r.diagnostic, id=r.id, priority=r.priority)
#     615         for r in group.analyzers
#     616     ]
#
# File ~\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\ScanAnalysis\scan_analysis\config\analysis_group_loader.py:332, in load_analysis_group(name_or_path, config_dir)
#     326         raise ValueError(
#     327             "config_dir is required when name_or_path is a string. "
#     328             "Pass an explicit Path to load_analysis_group(), or "
#     329             "supply config_dir."
#     330         )
#     331     base_dir = Path(config_dir)
# --> 332     group_path = _resolve_group_path(name_or_path, base_dir)
#     334 analyzer_index = discover_analyzers(base_dir)
#     336 with open(group_path, "r") as f:
#
# File ~\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins\ScanAnalysis\scan_analysis\config\analysis_group_loader.py:361, in _resolve_group_path(name, base_dir)
#     356 if candidates:
#     357     raise ValueError(
#     358         f"Group name '{name}' is ambiguous; matches: {sorted(candidates)}. "
#     359         f"Use the path-like form (e.g. 'HTU/{name}') to disambiguate."
#     360     )
# --> 361 raise FileNotFoundError(
#     362     f"Group '{name}' not found under {base_dir / 'groups'}. "
#     363     f"Known groups: {sorted(index)}"
#     364 )
#
# FileNotFoundError: Group 'Undulator_test' not found under C:\Users\loasis.LOASIS\Desktop\Scripts\People\Rachel\git_repos\GEECS-Plugins-Configs\scan_analysis_configs\groups. Known groups: ['HTT/HTT_MagSpec', 'HTT/VHEE', 'HTT_MagSpec', 'HTU/HTU_haso_only', 'HTU/HTU_opt', 'HTU/HTU_slow_analysis', 'HTU/Visa', 'HTU/baseline', 'HTU/htu_test', 'HTU/htu_variational', 'HTU_haso_only', 'HTU_opt', 'HTU_slow_analysis', 'PW-Laser', 'PW-Laser/PW-Laser', 'PW/PW_frog_onl', 'PW_frog_onl', 'VHEE', 'Visa', 'baseline', 'htu_test', 'htu_variational']
